# %%
# Importing Image class from PIL module
from PIL import Image

# Opens a image in RGB mode
im1 = Image.open(r"1m.jpg")

# Size of the image in pixels (size of original image)
# (This is not mandatory)
width, height = im1.size

# Setting the points for cropped image
left = 10
top = height / 10
right = 200
bottom = 3 * height / 4

# Cropped image of above dimension
# (It will not change original image)
im2 = im1.crop((left, top, right, bottom))

# Shows the image in image viewer
im2.show()
# Out:
# <PIL.Image.Image image mode=RGB size=190x2496 at 0x7F39EAF87C10>

# %%
#2nd code
# Importing Image class from PIL module
from PIL import Image

# Opens a image in RGB mode
im = Image.open(r"1m.jpg")

# Setting the points for cropped image
left = 177
top = 65
right = 360
bottom = 270

# Cropped image of above dimension
# (It will not change original image)
im1 = im.crop((left, top, right, bottom))

# Shows the image in image viewer
im1.show()
# Out:
# <PIL.Image.Image image mode=RGB size=183x205 at 0x7F39EAF87D90>
